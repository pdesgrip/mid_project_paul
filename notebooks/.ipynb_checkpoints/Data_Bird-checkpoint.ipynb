# %%
# import neccessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Preliminary examination
# Read smaller part of data file (10000 rows) and show sample using t delimiter as it's a txt file

#data = pd.read_csv(r'..\data\raw\ebd_NL_201501_202309_smp_relAug-2023.txt', nrows=10000, delimiter='\t')
data_full = pd.read_csv(r'..\data\raw\ebd_NL_201501_202309_smp_relAug-2023.txt', delimiter='\t')
data = data_full.sample(n=10000, random_state=42)  # random_state for reproducibility

print(data)


data.head()
# Out:
# C:\Users\desgr\AppData\Local\Temp\ipykernel_26628\129888860.py:5: DtypeWarning: Columns (19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_full = pd.read_csv(r'..\data\raw\ebd_NL_201501_202309_smp_relAug-2023.txt', delimiter='\t')
#                                 GLOBAL UNIQUE IDENTIFIER  \
# 988538   URN:CornellLabOfOrnithology:EBIRD:OBS1231543425
# 815791   URN:CornellLabOfOrnithology:EBIRD:OBS1108155474
# 1538863  URN:CornellLabOfOrnithology:EBIRD:OBS1668883279
# 360725    URN:CornellLabOfOrnithology:EBIRD:OBS737758941
# 1791352  URN:CornellLabOfOrnithology:EBIRD:OBS1809452658
# ...                                                  ...
# 614988    URN:CornellLabOfOrnithology:EBIRD:OBS935047078
# 20560     URN:CornellLabOfOrnithology:EBIRD:OBS646184988
# 582049    URN:CornellLabOfOrnithology:EBIRD:OBS932451526
# 93921     URN:CornellLabOfOrnithology:EBIRD:OBS450144359
# 680419    URN:CornellLabOfOrnithology:EBIRD:OBS979859409
#
#                    LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  \
# 988538   2021-09-06 08:08:53.918924             6118  species
# 815791   2022-10-21 16:39:18.661917            31809  species
# 1538863  2023-03-29 16:21:55.497973            26675  species
# 360725   2022-10-22 22:18:10.571624            23610  species
# 1791352  2023-08-22 14:20:14.089265              505  species
# ...                             ...              ...      ...
# 614988   2022-10-22 22:13:34.472416            23137  species
# 20560           2018-08-06 01:27:02             7531  species
# 582049          2020-05-26 19:45:22            21672  species
# 93921           2018-08-05 18:01:00            21672  species
# 680419    2021-03-17 22:01:43.63805             6386  species
#
#          TAXON CONCEPT ID         COMMON NAME             SCIENTIFIC NAME  \
# 988538   avibase-A7B17EFC     Green Sandpiper             Tringa ochropus
# 815791   avibase-32635892     Eurasian Linnet           Linaria cannabina
# 1538863  avibase-AF700208       Eurasian Wren     Troglodytes troglodytes
# 360725   avibase-58C502EA        Barn Swallow             Hirundo rustica
# 1791352  avibase-85625D75             Mallard          Anas platyrhynchos
# ...                   ...                 ...                         ...
# 614988   avibase-FED5AED5       Sedge Warbler  Acrocephalus schoenobaenus
# 20560    avibase-A0A584C1  Eurasian Spoonbill         Platalea leucorodia
# 582049   avibase-E15BC0CB           Great Tit                 Parus major
# 93921    avibase-E15BC0CB           Great Tit                 Parus major
# 680419   avibase-FB02DD96   Black-headed Gull  Chroicocephalus ridibundus
#
#         SUBSPECIES COMMON NAME SUBSPECIES SCIENTIFIC NAME EXOTIC CODE  ...  \
# 988538                     NaN                        NaN         NaN  ...
# 815791                     NaN                        NaN         NaN  ...
# 1538863                    NaN                        NaN         NaN  ...
# 360725                     NaN                        NaN         NaN  ...
# 1791352                    NaN                        NaN         NaN  ...
# ...                        ...                        ...         ...  ...
# 614988                     NaN                        NaN         NaN  ...
# 20560                      NaN                        NaN         NaN  ...
# 582049                     NaN                        NaN         NaN  ...
# 93921                      NaN                        NaN         NaN  ...
# 680419                     NaN                        NaN         NaN  ...
#
#         NUMBER OBSERVERS ALL SPECIES REPORTED GROUP IDENTIFIER HAS MEDIA  \
# 988538               1.0                    1              NaN         0
# 815791               1.0                    1              NaN         0
# 1538863              1.0                    1              NaN         0
# 360725               1.0                    1              NaN         0
# 1791352              1.0                    1              NaN         0
# ...                  ...                  ...              ...       ...
# 614988               1.0                    1              NaN         0
# 20560                1.0                    0              NaN         0
# 582049               2.0                    1              NaN         0
# 93921                1.0                    1              NaN         0
# 680419               6.0                    1              NaN         0
#
#         APPROVED REVIEWED REASON TRIP COMMENTS SPECIES COMMENTS Unnamed: 49
# 988538         1        0    NaN           NaN              NaN         NaN
# 815791         1        0    NaN           NaN              NaN         NaN
# 1538863        1        0    NaN           NaN              NaN         NaN
# 360725         1        0    NaN           NaN              NaN         NaN
# 1791352        1        0    NaN           NaN              NaN         NaN
# ...          ...      ...    ...           ...              ...         ...
# 614988         1        0    NaN           NaN              NaN         NaN
# 20560          1        0    NaN           NaN              NaN         NaN
# 582049         1        0    NaN           NaN              NaN         NaN
# 93921          1        0    NaN           NaN              NaN         NaN
# 680419         1        0    NaN           NaN              NaN         NaN
#
# [10000 rows x 50 columns]
#                                 GLOBAL UNIQUE IDENTIFIER  \
# 988538   URN:CornellLabOfOrnithology:EBIRD:OBS1231543425
# 815791   URN:CornellLabOfOrnithology:EBIRD:OBS1108155474
# 1538863  URN:CornellLabOfOrnithology:EBIRD:OBS1668883279
# 360725    URN:CornellLabOfOrnithology:EBIRD:OBS737758941
# 1791352  URN:CornellLabOfOrnithology:EBIRD:OBS1809452658
#
#                    LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  \
# 988538   2021-09-06 08:08:53.918924             6118  species
# 815791   2022-10-21 16:39:18.661917            31809  species
# 1538863  2023-03-29 16:21:55.497973            26675  species
# 360725   2022-10-22 22:18:10.571624            23610  species
# 1791352  2023-08-22 14:20:14.089265              505  species
#
#          TAXON CONCEPT ID      COMMON NAME          SCIENTIFIC NAME  \
# 988538   avibase-A7B17EFC  Green Sandpiper          Tringa ochropus
# 815791   avibase-32635892  Eurasian Linnet        Linaria cannabina
# 1538863  avibase-AF700208    Eurasian Wren  Troglodytes troglodytes
# 360725   avibase-58C502EA     Barn Swallow          Hirundo rustica
# 1791352  avibase-85625D75          Mallard       Anas platyrhynchos
#
#         SUBSPECIES COMMON NAME SUBSPECIES SCIENTIFIC NAME EXOTIC CODE  ...  \
# 988538                     NaN                        NaN         NaN  ...
# 815791                     NaN                        NaN         NaN  ...
# 1538863                    NaN                        NaN         NaN  ...
# 360725                     NaN                        NaN         NaN  ...
# 1791352                    NaN                        NaN         NaN  ...
#
#         NUMBER OBSERVERS ALL SPECIES REPORTED GROUP IDENTIFIER HAS MEDIA  \
# 988538               1.0                    1              NaN         0
# 815791               1.0                    1              NaN         0
# 1538863              1.0                    1              NaN         0
# 360725               1.0                    1              NaN         0
# 1791352              1.0                    1              NaN         0
#
#         APPROVED REVIEWED REASON TRIP COMMENTS SPECIES COMMENTS Unnamed: 49
# 988538         1        0    NaN           NaN              NaN         NaN
# 815791         1        0    NaN           NaN              NaN         NaN
# 1538863        1        0    NaN           NaN              NaN         NaN
# 360725         1        0    NaN           NaN              NaN         NaN
# 1791352        1        0    NaN           NaN              NaN         NaN
#
# [5 rows x 50 columns]

# %%
data.columns
# Out:
# Index(['GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE', 'TAXONOMIC ORDER',
#        'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME', 'SCIENTIFIC NAME',
#        'SUBSPECIES COMMON NAME', 'SUBSPECIES SCIENTIFIC NAME', 'EXOTIC CODE',
#        'OBSERVATION COUNT', 'BREEDING CODE', 'BREEDING CATEGORY',
#        'BEHAVIOR CODE', 'AGE/SEX', 'COUNTRY', 'COUNTRY CODE', 'STATE',
#        'STATE CODE', 'COUNTY', 'COUNTY CODE', 'IBA CODE', 'BCR CODE',
#        'USFWS CODE', 'ATLAS BLOCK', 'LOCALITY', 'LOCALITY ID', 'LOCALITY TYPE',
#        'LATITUDE', 'LONGITUDE', 'OBSERVATION DATE',
#        'TIME OBSERVATIONS STARTED', 'OBSERVER ID', 'SAMPLING EVENT IDENTIFIER',
#        'PROTOCOL TYPE', 'PROTOCOL CODE', 'PROJECT CODE', 'DURATION MINUTES',
#        'EFFORT DISTANCE KM', 'EFFORT AREA HA', 'NUMBER OBSERVERS',
#        'ALL SPECIES REPORTED', 'GROUP IDENTIFIER', 'HAS MEDIA', 'APPROVED',
#        'REVIEWED', 'REASON', 'TRIP COMMENTS', 'SPECIES COMMENTS',
#        'Unnamed: 49'],
#       dtype='object')

# %%
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 988538 to 680419
# Data columns (total 50 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   GLOBAL UNIQUE IDENTIFIER    10000 non-null  object
#  1   LAST EDITED DATE            10000 non-null  object
#  2   TAXONOMIC ORDER             10000 non-null  int64
#  3   CATEGORY                    10000 non-null  object
#  4   TAXON CONCEPT ID            10000 non-null  object
#  5   COMMON NAME                 10000 non-null  object
#  6   SCIENTIFIC NAME             10000 non-null  object
#  7   SUBSPECIES COMMON NAME      279 non-null    object
#  8   SUBSPECIES SCIENTIFIC NAME  279 non-null    object
#  9   EXOTIC CODE                 431 non-null    object
#  10  OBSERVATION COUNT           10000 non-null  object
#  11  BREEDING CODE               244 non-null    object
#  12  BREEDING CATEGORY           244 non-null    object
#  13  BEHAVIOR CODE               244 non-null    object
#  14  AGE/SEX                     41 non-null     object
#  15  COUNTRY                     10000 non-null  object
#  16  COUNTRY CODE                10000 non-null  object
#  17  STATE                       10000 non-null  object
#  18  STATE CODE                  10000 non-null  object
#  19  COUNTY                      1 non-null      object
#  20  COUNTY CODE                 1 non-null      object
#  21  IBA CODE                    342 non-null    object
#  22  BCR CODE                    0 non-null      float64
#  23  USFWS CODE                  0 non-null      float64
#  24  ATLAS BLOCK                 0 non-null      float64
#  25  LOCALITY                    10000 non-null  object
#  26  LOCALITY ID                 10000 non-null  object
#  27  LOCALITY TYPE               10000 non-null  object
#  28  LATITUDE                    10000 non-null  float64
#  29  LONGITUDE                   10000 non-null  float64
#  30  OBSERVATION DATE            10000 non-null  object
#  31  TIME OBSERVATIONS STARTED   9614 non-null   object
#  32  OBSERVER ID                 10000 non-null  object
#  33  SAMPLING EVENT IDENTIFIER   10000 non-null  object
#  34  PROTOCOL TYPE               10000 non-null  object
#  35  PROTOCOL CODE               10000 non-null  object
#  36  PROJECT CODE                10000 non-null  object
#  37  DURATION MINUTES            9137 non-null   float64
#  38  EFFORT DISTANCE KM          7572 non-null   float64
#  39  EFFORT AREA HA              5 non-null      float64
#  40  NUMBER OBSERVERS            9651 non-null   float64
#  41  ALL SPECIES REPORTED        10000 non-null  int64
#  42  GROUP IDENTIFIER            1940 non-null   object
#  43  HAS MEDIA                   10000 non-null  int64
#  44  APPROVED                    10000 non-null  int64
#  45  REVIEWED                    10000 non-null  int64
#  46  REASON                      0 non-null      float64
#  47  TRIP COMMENTS               517 non-null    object
#  48  SPECIES COMMENTS            356 non-null    object
#  49  Unnamed: 49                 0 non-null      float64
# dtypes: float64(11), int64(5), object(34)
# memory usage: 3.9+ MB
# None

# %%
# Function to sample some random rows

def random_sample_data(df, rows=20):
    
    ''' this function samples a random selection of
        20 rows within the dataframe and shows 
        the results'''
    
    sampled_data = df.sample(rows)
    for col in df.columns:
        print(f"Column: {col}")
        print(sampled_data[col])
        print("\n" + "-"*50 + "\n")

display(random_sample_data(data))
# Out:
# Column: GLOBAL UNIQUE IDENTIFIER
# 160899      URN:CornellLabOfOrnithology:EBIRD:OBS528846491
# 505474      URN:CornellLabOfOrnithology:EBIRD:OBS846540251
# 624177      URN:CornellLabOfOrnithology:EBIRD:OBS937107404
# 1579362    URN:CornellLabOfOrnithology:EBIRD:OBS1672085122
# 535593      URN:CornellLabOfOrnithology:EBIRD:OBS880729446
# 400309      URN:CornellLabOfOrnithology:EBIRD:OBS939589637
# 386884      URN:CornellLabOfOrnithology:EBIRD:OBS766323870
# 1769912    URN:CornellLabOfOrnithology:EBIRD:OBS1782294238
# 1210188    URN:CornellLabOfOrnithology:EBIRD:OBS1444654243
# 1600936    URN:CornellLabOfOrnithology:EBIRD:OBS1673209294
# 560270      URN:CornellLabOfOrnithology:EBIRD:OBS887024748
# 1391930    URN:CornellLabOfOrnithology:EBIRD:OBS1541410173
# 263728      URN:CornellLabOfOrnithology:EBIRD:OBS631909482
# 1166993    URN:CornellLabOfOrnithology:EBIRD:OBS1392021023
# 565691      URN:CornellLabOfOrnithology:EBIRD:OBS893454839
# 1730765    URN:CornellLabOfOrnithology:EBIRD:OBS1766468235
# 1570800    URN:CornellLabOfOrnithology:EBIRD:OBS1684130457
# 1645981    URN:CornellLabOfOrnithology:EBIRD:OBS1747398778
# 1439336    URN:CornellLabOfOrnithology:EBIRD:OBS1580899969
# 1404359    URN:CornellLabOfOrnithology:EBIRD:OBS1564853838
# Name: GLOBAL UNIQUE IDENTIFIER, dtype: object
#
# --------------------------------------------------
#
# Column: LAST EDITED DATE
# 160899     2021-03-30 04:39:44.434798
# 505474      2021-03-17 22:01:43.63805
# 624177     2022-10-22 22:27:53.006004
# 1579362    2023-04-02 07:38:27.610095
# 535593     2022-10-22 22:22:20.999835
# 400309     2022-10-22 22:13:37.175069
# 386884            2020-07-31 10:14:16
# 1769912    2023-07-14 02:48:27.353083
# 1210188    2022-10-22 22:17:24.640046
# 1600936    2023-04-03 05:34:38.306528
# 560270            2020-04-05 10:17:54
# 1391930    2022-11-06 17:21:17.421838
# 263728      2021-04-02 00:00:25.78199
# 1166993    2022-10-22 22:21:06.537372
# 565691     2022-10-22 22:17:41.858896
# 1730765    2023-07-01 05:20:18.526896
# 1570800    2023-04-13 17:54:04.371081
# 1645981    2023-06-01 00:58:52.497013
# 1439336      2022-12-13 16:20:31.3057
# 1404359    2022-11-19 13:36:27.366492
# Name: LAST EDITED DATE, dtype: object
#
# --------------------------------------------------
#
# Column: TAXONOMIC ORDER
# 160899      7299
# 505474      6419
# 624177      2033
# 1579362    30866
# 535593     21611
# 400309     30866
# 386884     26675
# 1769912    30886
# 1210188    26675
# 1600936    31674
# 560270     21073
# 1391930      548
# 263728       468
# 1166993    32132
# 565691      6623
# 1730765    21073
# 1570800    30886
# 1645981    24258
# 1439336     7300
# 1404359     6419
# Name: TAXONOMIC ORDER, dtype: int64
#
# --------------------------------------------------
#
# Column: CATEGORY
# 160899     species
# 505474     species
# 624177     species
# 1579362    species
# 535593     species
# 400309     species
# 386884     species
# 1769912    species
# 1210188    species
# 1600936    species
# 560270     species
# 1391930    species
# 263728     species
# 1166993    species
# 565691     species
# 1730765    species
# 1570800    species
# 1645981    species
# 1439336       issf
# 1404359    species
# Name: CATEGORY, dtype: object
#
# --------------------------------------------------
#
# Column: TAXON CONCEPT ID
# 160899     avibase-6429024D
# 505474     avibase-00DA9D91
# 624177     avibase-0C1EFC9B
# 1579362    avibase-26530C86
# 535593     avibase-9BE53D34
# 400309     avibase-26530C86
# 386884     avibase-AF700208
# 1769912    avibase-240E3390
# 1210188    avibase-AF700208
# 1600936    avibase-65BD2033
# 560270     avibase-26FB62DA
# 1391930    avibase-56CCA717
# 263728     avibase-C235A4D7
# 1166993    avibase-C0B97874
# 565691     avibase-4D2FF6F1
# 1730765    avibase-26FB62DA
# 1570800    avibase-240E3390
# 1645981    avibase-572C4C7F
# 1439336    avibase-0DB2F2AE
# 1404359    avibase-00DA9D91
# Name: TAXON CONCEPT ID, dtype: object
#
# --------------------------------------------------
#
# Column: COMMON NAME
# 160899                 Gray Heron
# 505474                Common Gull
# 624177     Eurasian Collared-Dove
# 1579362                   Dunnock
# 535593          Eurasian Blue Tit
# 400309                    Dunnock
# 386884              Eurasian Wren
# 1769912             House Sparrow
# 1210188             Eurasian Wren
# 1600936       European Greenfinch
# 560270               Carrion Crow
# 1391930          Northern Pintail
# 263728                    Gadwall
# 1166993              Reed Bunting
# 565691                Common Tern
# 1730765              Carrion Crow
# 1570800             House Sparrow
# 1645981              Wood Warbler
# 1439336                Gray Heron
# 1404359               Common Gull
# Name: COMMON NAME, dtype: object
#
# --------------------------------------------------
#
# Column: SCIENTIFIC NAME
# 160899               Ardea cinerea
# 505474                 Larus canus
# 624177       Streptopelia decaocto
# 1579362         Prunella modularis
# 535593         Cyanistes caeruleus
# 400309          Prunella modularis
# 386884     Troglodytes troglodytes
# 1769912          Passer domesticus
# 1210188    Troglodytes troglodytes
# 1600936            Chloris chloris
# 560270               Corvus corone
# 1391930                 Anas acuta
# 263728             Mareca strepera
# 1166993       Emberiza schoeniclus
# 565691              Sterna hirundo
# 1730765              Corvus corone
# 1570800          Passer domesticus
# 1645981    Phylloscopus sibilatrix
# 1439336              Ardea cinerea
# 1404359                Larus canus
# Name: SCIENTIFIC NAME, dtype: object
#
# --------------------------------------------------
#
# Column: SUBSPECIES COMMON NAME
# 160899                   NaN
# 505474                   NaN
# 624177                   NaN
# 1579362                  NaN
# 535593                   NaN
# 400309                   NaN
# 386884                   NaN
# 1769912                  NaN
# 1210188                  NaN
# 1600936                  NaN
# 560270                   NaN
# 1391930                  NaN
# 263728                   NaN
# 1166993                  NaN
# 565691                   NaN
# 1730765                  NaN
# 1570800                  NaN
# 1645981                  NaN
# 1439336    Gray Heron (Gray)
# 1404359                  NaN
# Name: SUBSPECIES COMMON NAME, dtype: object
#
# --------------------------------------------------
#
# Column: SUBSPECIES SCIENTIFIC NAME
# 160899                             NaN
# 505474                             NaN
# 624177                             NaN
# 1579362                            NaN
# 535593                             NaN
# 400309                             NaN
# 386884                             NaN
# 1769912                            NaN
# 1210188                            NaN
# 1600936                            NaN
# 560270                             NaN
# 1391930                            NaN
# 263728                             NaN
# 1166993                            NaN
# 565691                             NaN
# 1730765                            NaN
# 1570800                            NaN
# 1645981                            NaN
# 1439336    Ardea cinerea cinerea/jouyi
# 1404359                            NaN
# Name: SUBSPECIES SCIENTIFIC NAME, dtype: object
#
# --------------------------------------------------
#
# Column: EXOTIC CODE
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: EXOTIC CODE, dtype: object
#
# --------------------------------------------------
#
# Column: OBSERVATION COUNT
# 160899      1
# 505474      1
# 624177      4
# 1579362     2
# 535593      2
# 400309      X
# 386884      2
# 1769912     3
# 1210188     1
# 1600936     X
# 560270     15
# 1391930     X
# 263728      2
# 1166993     3
# 565691      1
# 1730765     6
# 1570800     X
# 1645981     X
# 1439336     4
# 1404359     X
# Name: OBSERVATION COUNT, dtype: object
#
# --------------------------------------------------
#
# Column: BREEDING CODE
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: BREEDING CODE, dtype: object
#
# --------------------------------------------------
#
# Column: BREEDING CATEGORY
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: BREEDING CATEGORY, dtype: object
#
# --------------------------------------------------
#
# Column: BEHAVIOR CODE
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: BEHAVIOR CODE, dtype: object
#
# --------------------------------------------------
#
# Column: AGE/SEX
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: AGE/SEX, dtype: object
#
# --------------------------------------------------
#
# Column: COUNTRY
# 160899     Netherlands
# 505474     Netherlands
# 624177     Netherlands
# 1579362    Netherlands
# 535593     Netherlands
# 400309     Netherlands
# 386884     Netherlands
# 1769912    Netherlands
# 1210188    Netherlands
# 1600936    Netherlands
# 560270     Netherlands
# 1391930    Netherlands
# 263728     Netherlands
# 1166993    Netherlands
# 565691     Netherlands
# 1730765    Netherlands
# 1570800    Netherlands
# 1645981    Netherlands
# 1439336    Netherlands
# 1404359    Netherlands
# Name: COUNTRY, dtype: object
#
# --------------------------------------------------
#
# Column: COUNTRY CODE
# 160899     NL
# 505474     NL
# 624177     NL
# 1579362    NL
# 535593     NL
# 400309     NL
# 386884     NL
# 1769912    NL
# 1210188    NL
# 1600936    NL
# 560270     NL
# 1391930    NL
# 263728     NL
# 1166993    NL
# 565691     NL
# 1730765    NL
# 1570800    NL
# 1645981    NL
# 1439336    NL
# 1404359    NL
# Name: COUNTRY CODE, dtype: object
#
# --------------------------------------------------
#
# Column: STATE
# 160899     Noord-Brabant
# 505474     Noord-Brabant
# 624177     Noord-Brabant
# 1579362    Noord-Brabant
# 535593     Noord-Brabant
# 400309      Zuid-Holland
# 386884     Noord-Brabant
# 1769912       Overijssel
# 1210188        Flevoland
# 1600936       Overijssel
# 560270     Noord-Brabant
# 1391930    Noord-Holland
# 263728     Noord-Holland
# 1166993       Gelderland
# 565691     Noord-Holland
# 1730765          Utrecht
# 1570800       Gelderland
# 1645981       Gelderland
# 1439336    Noord-Holland
# 1404359        Flevoland
# Name: STATE, dtype: object
#
# --------------------------------------------------
#
# Column: STATE CODE
# 160899     NL-NB
# 505474     NL-NB
# 624177     NL-NB
# 1579362    NL-NB
# 535593     NL-NB
# 400309     NL-ZH
# 386884     NL-NB
# 1769912    NL-OV
# 1210188    NL-FL
# 1600936    NL-OV
# 560270     NL-NB
# 1391930    NL-NH
# 263728     NL-NH
# 1166993    NL-GE
# 565691     NL-NH
# 1730765    NL-UT
# 1570800    NL-GE
# 1645981    NL-GE
# 1439336    NL-NH
# 1404359    NL-FL
# Name: STATE CODE, dtype: object
#
# --------------------------------------------------
#
# Column: COUNTY
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: COUNTY, dtype: object
#
# --------------------------------------------------
#
# Column: COUNTY CODE
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: COUNTY CODE, dtype: object
#
# --------------------------------------------------
#
# Column: IBA CODE
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: IBA CODE, dtype: object
#
# --------------------------------------------------
#
# Column: BCR CODE
# 160899    NaN
# 505474    NaN
# 624177    NaN
# 1579362   NaN
# 535593    NaN
# 400309    NaN
# 386884    NaN
# 1769912   NaN
# 1210188   NaN
# 1600936   NaN
# 560270    NaN
# 1391930   NaN
# 263728    NaN
# 1166993   NaN
# 565691    NaN
# 1730765   NaN
# 1570800   NaN
# 1645981   NaN
# 1439336   NaN
# 1404359   NaN
# Name: BCR CODE, dtype: float64
#
# --------------------------------------------------
#
# Column: USFWS CODE
# 160899    NaN
# 505474    NaN
# 624177    NaN
# 1579362   NaN
# 535593    NaN
# 400309    NaN
# 386884    NaN
# 1769912   NaN
# 1210188   NaN
# 1600936   NaN
# 560270    NaN
# 1391930   NaN
# 263728    NaN
# 1166993   NaN
# 565691    NaN
# 1730765   NaN
# 1570800   NaN
# 1645981   NaN
# 1439336   NaN
# 1404359   NaN
# Name: USFWS CODE, dtype: float64
#
# --------------------------------------------------
#
# Column: ATLAS BLOCK
# 160899    NaN
# 505474    NaN
# 624177    NaN
# 1579362   NaN
# 535593    NaN
# 400309    NaN
# 386884    NaN
# 1769912   NaN
# 1210188   NaN
# 1600936   NaN
# 560270    NaN
# 1391930   NaN
# 263728    NaN
# 1166993   NaN
# 565691    NaN
# 1730765   NaN
# 1570800   NaN
# 1645981   NaN
# 1439336   NaN
# 1404359   NaN
# Name: ATLAS BLOCK, dtype: float64
#
# --------------------------------------------------
#
# Column: LOCALITY
# 160899                            Sint-Oedenrode--Dommelpark
# 505474                                             Biesbosch
# 624177     Lage Zwaluwe - Zevenbergschen Hoek - Langeweg,...
# 1579362                                            Biesbosch
# 535593                                     Het Bossche Broek
# 400309                                         Groene Jonker
# 386884     Dooibroek, Sint-Michielsgestel, Noord-Brabant,...
# 1769912    21 Koningin Wilhelminalaan, Bathmen, Overijsse...
# 1210188                 Lepelaarplassen--Trekvogelgraslandje
# 1600936                                Vogelkijkhut de Pluus
# 560270               Pannenhoef, Etten-Leur NL-Noord-Brabant
# 1391930                 Texel--Horspolders & De Horsmeertjes
# 263728     Tussen Twee Havens 9A, Enkhuizen NL-Noord-Holl...
# 1166993                              Ooijpolder--Tiengeboden
# 565691                                            Het Twiske
# 1730765                  Heidestein (Het Utrechts Landschap)
# 1570800                                   Klompenpad Heteren
# 1645981                                           Deelerwoud
# 1439336                              Amsterdam--Sarphatipark
# 1404359                Oostvaardersplassen--Bezoekerscentrum
# Name: LOCALITY, dtype: object
#
# --------------------------------------------------
#
# Column: LOCALITY ID
# 160899      L5134228
# 505474       L929762
# 624177     L11615361
# 1579362      L929762
# 535593     L10021507
# 400309      L9205555
# 386884      L9345441
# 1769912    L25917651
# 1210188     L1572981
# 1600936    L23365819
# 560270     L11064040
# 1391930     L2899025
# 263728      L7585001
# 1166993    L17940972
# 565691      L1534518
# 1730765     L3019502
# 1570800    L17019929
# 1645981     L7420129
# 1439336     L4788054
# 1404359    L21150425
# Name: LOCALITY ID, dtype: object
#
# --------------------------------------------------
#
# Column: LOCALITY TYPE
# 160899     H
# 505474     H
# 624177     P
# 1579362    H
# 535593     H
# 400309     P
# 386884     H
# 1769912    P
# 1210188    H
# 1600936    P
# 560270     P
# 1391930    H
# 263728     P
# 1166993    P
# 565691     H
# 1730765    H
# 1570800    P
# 1645981    H
# 1439336    H
# 1404359    H
# Name: LOCALITY TYPE, dtype: object
#
# --------------------------------------------------
#
# Column: LATITUDE
# 160899     51.567206
# 505474     51.761041
# 624177     51.688385
# 1579362    51.761041
# 535593     51.677611
# 400309     52.179169
# 386884     51.659340
# 1769912    52.247549
# 1210188    52.414949
# 1600936    52.482519
# 560270     51.520465
# 1391930    53.001252
# 263728     52.699419
# 1166993    51.858176
# 565691     52.447554
# 1730765    52.072684
# 1570800    51.961978
# 1645981    52.074020
# 1439336    52.354474
# 1404359    52.457343
# Name: LATITUDE, dtype: float64
#
# --------------------------------------------------
#
# Column: LONGITUDE
# 160899     5.457019
# 505474     4.769440
# 624177     4.699010
# 1579362    4.769440
# 535593     5.302496
# 400309     4.833682
# 386884     5.320182
# 1769912    6.296925
# 1210188    5.222511
# 1600936    6.667328
# 560270     4.648160
# 1391930    4.743733
# 263728     5.290389
# 1166993    5.900847
# 565691     4.894498
# 1730765    5.277557
# 1570800    5.755870
# 1645981    5.895839
# 1439336    4.896255
# 1404359    5.419435
# Name: LONGITUDE, dtype: float64
#
# --------------------------------------------------
#
# Column: OBSERVATION DATE
# 160899     2017-08-30
# 505474     2020-01-04
# 624177     2020-06-03
# 1579362    2023-04-02
# 535593     2020-03-19
# 400309     2019-05-06
# 386884     2019-05-26
# 1769912    2023-07-14
# 1210188    2022-05-28
# 1600936    2023-04-03
# 560270     2020-04-01
# 1391930    2022-10-13
# 263728     2018-06-17
# 1166993    2022-04-14
# 565691     2020-04-12
# 1730765    2023-06-23
# 1570800    2023-04-13
# 1645981    2023-05-31
# 1439336    2022-12-11
# 1404359    2022-11-19
# Name: OBSERVATION DATE, dtype: object
#
# --------------------------------------------------
#
# Column: TIME OBSERVATIONS STARTED
# 160899     17:29:00
# 505474     11:00:00
# 624177     19:00:00
# 1579362    06:40:00
# 535593     16:53:00
# 400309     11:28:00
# 386884     09:55:00
# 1769912    08:17:00
# 1210188    11:37:00
# 1600936    06:15:00
# 560270     14:30:00
# 1391930    15:05:00
# 263728     10:19:00
# 1166993    19:53:00
# 565691     11:03:00
# 1730765    08:00:00
# 1570800    18:19:00
# 1645981    19:49:00
# 1439336    09:45:00
# 1404359    10:52:00
# Name: TIME OBSERVATIONS STARTED, dtype: object
#
# --------------------------------------------------
#
# Column: OBSERVER ID
# 160899      obsr264969
# 505474     obsr1461465
# 624177     obsr1341767
# 1579362     obsr331082
# 535593     obsr1498204
# 400309     obsr1743420
# 386884      obsr239797
# 1769912     obsr143271
# 1210188    obsr3185428
# 1600936    obsr3444412
# 560270     obsr1341767
# 1391930    obsr1356205
# 263728     obsr1087456
# 1166993    obsr1793032
# 565691     obsr1206854
# 1730765     obsr636717
# 1570800    obsr2120803
# 1645981    obsr1500863
# 1439336     obsr233336
# 1404359    obsr1030704
# Name: OBSERVER ID, dtype: object
#
# --------------------------------------------------
#
# Column: SAMPLING EVENT IDENTIFIER
# 160899      S38904985
# 505474      S62993897
# 624177      S70017532
# 1579362    S132458308
# 535593      S65976636
# 400309      S70195318
# 386884      S56750486
# 1769912    S144482584
# 1210188    S111482522
# 1600936    S132567275
# 560270      S66479461
# 1391930    S120765822
# 263728      S46610454
# 1166993    S107031910
# 565691      S67068339
# 1730765    S142421464
# 1570800    S133637559
# 1645981    S140074957
# 1439336    S123925014
# 1404359    S122643289
# Name: SAMPLING EVENT IDENTIFIER, dtype: object
#
# --------------------------------------------------
#
# Column: PROTOCOL TYPE
# 160899      Traveling
# 505474      Traveling
# 624177      Traveling
# 1579362     Traveling
# 535593      Traveling
# 400309      Traveling
# 386884     Stationary
# 1769912     Traveling
# 1210188     Traveling
# 1600936     Traveling
# 560270      Traveling
# 1391930     Traveling
# 263728      Traveling
# 1166993     Traveling
# 565691      Traveling
# 1730765     Traveling
# 1570800     Traveling
# 1645981     Traveling
# 1439336     Traveling
# 1404359     Traveling
# Name: PROTOCOL TYPE, dtype: object
#
# --------------------------------------------------
#
# Column: PROTOCOL CODE
# 160899     P22
# 505474     P22
# 624177     P22
# 1579362    P22
# 535593     P22
# 400309     P22
# 386884     P21
# 1769912    P22
# 1210188    P22
# 1600936    P22
# 560270     P22
# 1391930    P22
# 263728     P22
# 1166993    P22
# 565691     P22
# 1730765    P22
# 1570800    P22
# 1645981    P22
# 1439336    P22
# 1404359    P22
# Name: PROTOCOL CODE, dtype: object
#
# --------------------------------------------------
#
# Column: PROJECT CODE
# 160899     EBIRD
# 505474     EBIRD
# 624177     EBIRD
# 1579362    EBIRD
# 535593     EBIRD
# 400309     EBIRD
# 386884     EBIRD
# 1769912    EBIRD
# 1210188    EBIRD
# 1600936    EBIRD
# 560270     EBIRD
# 1391930    EBIRD
# 263728     EBIRD
# 1166993    EBIRD
# 565691     EBIRD
# 1730765    EBIRD
# 1570800    EBIRD
# 1645981    EBIRD
# 1439336    EBIRD
# 1404359    EBIRD
# Name: PROJECT CODE, dtype: object
#
# --------------------------------------------------
#
# Column: DURATION MINUTES
# 160899      27.0
# 505474     270.0
# 624177     180.0
# 1579362    300.0
# 535593     114.0
# 400309      90.0
# 386884      21.0
# 1769912     30.0
# 1210188    300.0
# 1600936    180.0
# 560270     100.0
# 1391930    145.0
# 263728     437.0
# 1166993     44.0
# 565691     120.0
# 1730765    150.0
# 1570800     90.0
# 1645981    116.0
# 1439336     60.0
# 1404359    141.0
# Name: DURATION MINUTES, dtype: float64
#
# --------------------------------------------------
#
# Column: EFFORT DISTANCE KM
# 160899      1.520
# 505474     18.000
# 624177     40.000
# 1579362    40.000
# 535593      7.710
# 400309      4.000
# 386884        NaN
# 1769912     1.046
# 1210188     3.000
# 1600936     4.000
# 560270      5.000
# 1391930     3.830
# 263728     37.031
# 1166993     1.018
# 565691      8.000
# 1730765     5.000
# 1570800     2.350
# 1645981     2.924
# 1439336     1.059
# 1404359     4.400
# Name: EFFORT DISTANCE KM, dtype: float64
#
# --------------------------------------------------
#
# Column: EFFORT AREA HA
# 160899    NaN
# 505474    NaN
# 624177    NaN
# 1579362   NaN
# 535593    NaN
# 400309    NaN
# 386884    NaN
# 1769912   NaN
# 1210188   NaN
# 1600936   NaN
# 560270    NaN
# 1391930   NaN
# 263728    NaN
# 1166993   NaN
# 565691    NaN
# 1730765   NaN
# 1570800   NaN
# 1645981   NaN
# 1439336   NaN
# 1404359   NaN
# Name: EFFORT AREA HA, dtype: float64
#
# --------------------------------------------------
#
# Column: NUMBER OBSERVERS
# 160899     1.0
# 505474     1.0
# 624177     2.0
# 1579362    1.0
# 535593     2.0
# 400309     1.0
# 386884     2.0
# 1769912    1.0
# 1210188    1.0
# 1600936    1.0
# 560270     2.0
# 1391930    2.0
# 263728     1.0
# 1166993    1.0
# 565691     2.0
# 1730765    1.0
# 1570800    1.0
# 1645981    5.0
# 1439336    1.0
# 1404359    2.0
# Name: NUMBER OBSERVERS, dtype: float64
#
# --------------------------------------------------
#
# Column: ALL SPECIES REPORTED
# 160899     1
# 505474     1
# 624177     1
# 1579362    1
# 535593     1
# 400309     1
# 386884     1
# 1769912    1
# 1210188    0
# 1600936    1
# 560270     1
# 1391930    1
# 263728     0
# 1166993    1
# 565691     1
# 1730765    1
# 1570800    1
# 1645981    0
# 1439336    1
# 1404359    1
# Name: ALL SPECIES REPORTED, dtype: int64
#
# --------------------------------------------------
#
# Column: GROUP IDENTIFIER
# 160899           NaN
# 505474           NaN
# 624177           NaN
# 1579362          NaN
# 535593           NaN
# 400309      G5431651
# 386884      G4221154
# 1769912          NaN
# 1210188          NaN
# 1600936          NaN
# 560270           NaN
# 1391930          NaN
# 263728           NaN
# 1166993          NaN
# 565691           NaN
# 1730765          NaN
# 1570800          NaN
# 1645981    G10357124
# 1439336          NaN
# 1404359     G9193673
# Name: GROUP IDENTIFIER, dtype: object
#
# --------------------------------------------------
#
# Column: HAS MEDIA
# 160899     0
# 505474     0
# 624177     0
# 1579362    0
# 535593     0
# 400309     0
# 386884     0
# 1769912    0
# 1210188    0
# 1600936    0
# 560270     0
# 1391930    1
# 263728     0
# 1166993    0
# 565691     0
# 1730765    0
# 1570800    0
# 1645981    0
# 1439336    0
# 1404359    1
# Name: HAS MEDIA, dtype: int64
#
# --------------------------------------------------
#
# Column: APPROVED
# 160899     1
# 505474     1
# 624177     1
# 1579362    1
# 535593     1
# 400309     1
# 386884     1
# 1769912    1
# 1210188    1
# 1600936    1
# 560270     1
# 1391930    1
# 263728     1
# 1166993    1
# 565691     1
# 1730765    1
# 1570800    1
# 1645981    1
# 1439336    1
# 1404359    1
# Name: APPROVED, dtype: int64
#
# --------------------------------------------------
#
# Column: REVIEWED
# 160899     0
# 505474     0
# 624177     0
# 1579362    0
# 535593     0
# 400309     0
# 386884     0
# 1769912    0
# 1210188    0
# 1600936    0
# 560270     0
# 1391930    0
# 263728     0
# 1166993    0
# 565691     0
# 1730765    0
# 1570800    0
# 1645981    0
# 1439336    0
# 1404359    0
# Name: REVIEWED, dtype: int64
#
# --------------------------------------------------
#
# Column: REASON
# 160899    NaN
# 505474    NaN
# 624177    NaN
# 1579362   NaN
# 535593    NaN
# 400309    NaN
# 386884    NaN
# 1769912   NaN
# 1210188   NaN
# 1600936   NaN
# 560270    NaN
# 1391930   NaN
# 263728    NaN
# 1166993   NaN
# 565691    NaN
# 1730765   NaN
# 1570800   NaN
# 1645981   NaN
# 1439336   NaN
# 1404359   NaN
# Name: REASON, dtype: float64
#
# --------------------------------------------------
#
# Column: TRIP COMMENTS
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: TRIP COMMENTS, dtype: object
#
# --------------------------------------------------
#
# Column: SPECIES COMMENTS
# 160899     NaN
# 505474     NaN
# 624177     NaN
# 1579362    NaN
# 535593     NaN
# 400309     NaN
# 386884     NaN
# 1769912    NaN
# 1210188    NaN
# 1600936    NaN
# 560270     NaN
# 1391930    NaN
# 263728     NaN
# 1166993    NaN
# 565691     NaN
# 1730765    NaN
# 1570800    NaN
# 1645981    NaN
# 1439336    NaN
# 1404359    NaN
# Name: SPECIES COMMENTS, dtype: object
#
# --------------------------------------------------
#
# Column: Unnamed: 49
# 160899    NaN
# 505474    NaN
# 624177    NaN
# 1579362   NaN
# 535593    NaN
# 400309    NaN
# 386884    NaN
# 1769912   NaN
# 1210188   NaN
# 1600936   NaN
# 560270    NaN
# 1391930   NaN
# 263728    NaN
# 1166993   NaN
# 565691    NaN
# 1730765   NaN
# 1570800   NaN
# 1645981   NaN
# 1439336   NaN
# 1404359   NaN
# Name: Unnamed: 49, dtype: float64
#
# --------------------------------------------------
# None

# %%
# the following columns need to be removed as they are not useful or contain no information [COUNTRY, COUNTY, COUNTY CODE, IBA CODE, BCR CODE, USFWS CODE, ATLAS BLOCK, 
# SAMPLING EVENT IDENTIFIER, PROJECT CODE, EFFORT AREA HA, GROUP IDENTIFIER, CATEGORY, SUBSPECIES COMMON NAME, SUBSPECIES SCIENTIFIC NAME,
# EXOTIC CODE, APPROVED, REVIEWED, REASON, Unnamed: 49]

columns_to_drop = ['COUNTRY', 'COUNTY', 'COUNTY CODE', 'IBA CODE', 'BCR CODE', 'USFWS CODE', 'ATLAS BLOCK', 'SAMPLING EVENT IDENTIFIER', 
                   'PROJECT CODE', 'EFFORT AREA HA', 'GROUP IDENTIFIER', 'CATEGORY', 'SUBSPECIES COMMON NAME', 'SUBSPECIES SCIENTIFIC NAME', 
                   'EXOTIC CODE', 'APPROVED', 'REVIEWED', 'REASON', 'Unnamed: 49']
data = data.drop(columns = columns_to_drop)

# %%
# Confirming columns were removed

print(data.shape)
# Out:
# (10000, 31)

# %%
unique_common_names_count = data['COMMON NAME'].nunique()
print(unique_common_names_count)
# Out:
# 271

# %%
# count frequency of sightings by the common name of the bird

sightings_count = data.groupby('COMMON NAME').size()
sorted_sightings = sightings_count.sort_values(ascending = False)
print (sorted_sightings)
# Out:
# COMMON NAME
# Eurasian Coot                 261
# Mallard                       258
# Eurasian Blackbird            254
# Common Wood-Pigeon            250
# Carrion Crow                  238
#                              ...
# Eurasian Dotterel               1
# Lesser White-fronted Goose      1
# Corn Bunting                    1
# Red-breasted Goose              1
# white egret sp.                 1
# Length: 271, dtype: int64

# %%
# Count the frequency of each bird
bird_counts = data['COMMON NAME'].value_counts()

# Display the top 20
top_50 = bird_counts.head(50)
print("Top 50:")
print(top_50)

print("\n")  # For a newline between the results

# Display the bottom 20
bottom_50 = bird_counts.tail(50)
print("Bottom 50:")
print(bottom_50)
# Out:
# Top 50:
# COMMON NAME
# Eurasian Coot               261
# Mallard                     258
# Eurasian Blackbird          254
# Common Wood-Pigeon          250
# Carrion Crow                238
# Great Tit                   231
# Graylag Goose               225
# Black-headed Gull           219
# Eurasian Magpie             212
# Eurasian Blue Tit           210
# Eurasian Jackdaw            193
# Great Cormorant             191
# Gray Heron                  189
# Common Chaffinch            185
# European Starling           165
# Common Buzzard              162
# Mute Swan                   159
# European Robin              151
# Eurasian Wren               151
# Eurasian Oystercatcher      147
# Great Spotted Woodpecker    139
# Great Crested Grebe         138
# House Sparrow               136
# Tufted Duck                 132
# Northern Lapwing            132
# Common Chiffchaff           130
# Gadwall                     126
# Herring Gull                124
# Egyptian Goose              123
# White Wagtail               109
# Eurasian Moorhen            107
# European Goldfinch          107
# Common Shelduck             101
# Lesser Black-backed Gull     99
# Eurasian Kestrel             98
# Eurasian Blackcap            97
# Stock Dove                   97
# Barn Swallow                 93
# Eurasian Jay                 90
# Canada Goose                 89
# Short-toed Treecreeper       82
# Reed Bunting                 82
# European Greenfinch          81
# Great Egret                  80
# Song Thrush                  76
# Eurasian Linnet              70
# Dunnock                      70
# Meadow Pipit                 69
# Eurasian Wigeon              68
# Northern Shoveler            68
# Name: count, dtype: int64
#
#
# Bottom 50:
# COMMON NAME
# European Turtle-Dove          2
# European Shag                 2
# Muscovy Duck                  2
# Horned Grebe                  2
# Yellow-browed Warbler         1
# Red Phalarope                 1
# Temminck's Stint              1
# cormorant sp.                 1
# Common Quail                  1
# Pygmy Cormorant               1
# tern sp.                      1
# Eurasian Eagle-Owl            1
# diurnal raptor sp.            1
# large alcid sp.               1
# Wood Duck                     1
# Lesser Gray Shrike            1
# Montagu's Harrier             1
# Ross's Gull                   1
# Corn Bunting                  1
# Black Kite                    1
# Arctic Tern                   1
# Alpine Swift                  1
# Yellow-browed Bunting         1
# goose sp.                     1
# Short-eared Owl               1
# Eurasian Dotterel             1
# Hume's Warbler                1
# Short-toed Snake-Eagle        1
# Common Redpoll                1
# Eurasian Nightjar             1
# Parrot Crossbill              1
# Lapland Longspur              1
# Buff-breasted Sandpiper       1
# Great Gray Shrike             1
# Hooded Crow                   1
# Whiskered Tern                1
# Eurasian Treecreeper          1
# Mandarin Duck                 1
# Baikal Teal                   1
# Eurasian Wryneck              1
# Ross's Goose                  1
# Great Skua                    1
# Bohemian Waxwing              1
# Lesser White-fronted Goose    1
# Swan Goose                    1
# King Eider                    1
# Red-necked Phalarope          1
# white egret sp.               1
# Red-breasted Goose            1
# Black-crowned Night-Heron     1
# Name: count, dtype: int64

# %%
# Count the frequency of each bird sighting
bird_counts = data['COMMON NAME'].value_counts()

# Extract the top 40
top_40 = bird_counts.head(40)

# Plot for top 40
plt.figure(figsize=(14,14))
sns.barplot(y=top_40.index, x=top_40.values, palette='viridis')
plt.title('Top 40 Most Frequent Bird Sightings')
plt.xlabel('Number of Sightings')
plt.ylabel('Bird Common Name')
plt.savefig('../images/bird_sightings.png')
plt.show()
# Out:
# C:\Users\desgr\AppData\Local\Temp\ipykernel_26628\2424539130.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_40.index, x=top_40.values, palette='viridis')

# %%
protocol_counts = data ['PROTOCOL CODE'].value_counts()
print(protocol_counts)
# Out:
# PROTOCOL CODE
# P22    7537
# P21    1511
# P20     636
# P62     308
# P33       8
# Name: count, dtype: int64

# %%
# Get a random sample of 50 rows from the "PROTOCOL TYPE" column
sample_protocol_type = data['PROTOCOL TYPE'].sample(50)

print(sample_protocol_type)
# Out:
# 1193994    Stationary
# 1776260     Traveling
# 1094734     Traveling
# 913391      Traveling
# 38849      Stationary
# 1177786     Traveling
# 433625     Incidental
# 424257      Traveling
# 1334724     Traveling
# 279026      Traveling
# 946161      Traveling
# 290734     Incidental
# 1292183     Traveling
# 37768       Traveling
# 56978      Stationary
# 1232466     Traveling
# 258049     Historical
# 497230      Traveling
# 1381839     Traveling
# 1769912     Traveling
# 1558263     Traveling
# 1477460     Traveling
# 604270     Historical
# 823442      Traveling
# 190904      Traveling
# 559803      Traveling
# 1188741     Traveling
# 1005488     Traveling
# 574008      Traveling
# 140086     Incidental
# 373110      Traveling
# 1108969     Traveling
# 863075      Traveling
# 1754189     Traveling
# 111010     Incidental
# 1380885     Traveling
# 187651      Traveling
# 389321      Traveling
# 1302682     Traveling
# 1789159     Traveling
# 1799909     Traveling
# 1314513    Stationary
# 183085      Traveling
# 610318      Traveling
# 1159789     Traveling
# 947761     Incidental
# 116727      Traveling
# 227587      Traveling
# 469289      Traveling
# 1594022     Traveling
# Name: PROTOCOL TYPE, dtype: object

# %%
grouped = data.groupby('PROTOCOL TYPE')

diversity_counts = grouped['COMMON NAME'].nunique()

sns.barplot (x=diversity_counts.index, y=diversity_counts.values)

plt.savefig('../images/sighting_types.png')

# %%
# plot the most sighted birds for each protocol tyoe

protocols_of_interest = ['Stationary', 'Traveling', 'Historical', 'Incidental']
filtered_data = data[data['PROTOCOL TYPE'].isin(protocols_of_interest)]
bird_counts_by_protocol = filtered_data.groupby(['PROTOCOL TYPE', 'COMMON NAME']).size().reset_index(name='COUNT')

N = 10
top_birds_by_protocol = bird_counts_by_protocol.groupby('PROTOCOL TYPE').apply(lambda x: x.nlargest(N, 'COUNT')).reset_index(drop=True)
palette = sns.color_palette("bright", 20)
plt.figure(figsize=(15, 8))
sns.barplot(data=top_birds_by_protocol, x='PROTOCOL TYPE', y='COUNT', hue='COMMON NAME', dodge=False, palette=palette)
plt.legend(loc='upper left')
plt.title('Top N Most Sighted Birds for Each Protocol')

plt.show()

# %%
protocols_of_interest = ['P20', 'P62', 'P21', 'P22']
filtered_data = data[data['PROTOCOL CODE'].isin(protocols_of_interest)]
bird_counts_by_protocol = filtered_data.groupby(['PROTOCOL CODE', 'COMMON NAME']).size().reset_index(name='COUNT')


N = 10
top_birds_by_protocol = bird_counts_by_protocol.groupby('PROTOCOL CODE').apply(lambda x: x.nlargest(N, 'COUNT')).reset_index(drop=True)

palette = sns.color_palette("Paired", 20)
plt.figure(figsize=(15, 8))
sns.barplot(data=top_birds_by_protocol, x='PROTOCOL CODE', y='COUNT', hue='COMMON NAME', dodge=False, palette=palette)
plt.legend(loc='upper right')
plt.title('Top N Most Sighted Birds for Each Protocol')
plt.show()

# %%
pivot_table = data.pivot_table(index='PROTOCOL CODE', columns='PROTOCOL TYPE', values='COMMON NAME', aggfunc='count')
print(pivot_table)
# Out:
# PROTOCOL TYPE  Banding  Historical  Incidental  Stationary  Traveling
# PROTOCOL CODE
# P20                NaN         NaN       636.0         NaN        NaN
# P21                NaN         NaN         NaN      1511.0        NaN
# P22                NaN         NaN         NaN         NaN     7537.0
# P33                8.0         NaN         NaN         NaN        NaN
# P62                NaN       308.0         NaN         NaN        NaN

# %%
top_birds_by_protocol_type = data.groupby(['PROTOCOL TYPE', 'COMMON NAME']).size().reset_index(name='COUNT')
top_10_by_protocol_type = top_birds_by_protocol_type.groupby('PROTOCOL TYPE').apply(lambda x: x.nlargest(10, 'COUNT')).reset_index(drop=True)
print(top_10_by_protocol_type)
# Out:
#    PROTOCOL TYPE             COMMON NAME  COUNT
# 0        Banding            Barn Swallow      1
# 1        Banding            Common Swift      1
# 2        Banding       Eurasian Blackcap      1
# 3        Banding  Eurasian Marsh-Harrier      1
# 4        Banding        Eurasian Wryneck      1
# 5        Banding               Great Tit      1
# 6        Banding           Marsh Warbler      1
# 7        Banding                 Redwing      1
# 8     Historical      Eurasian Blackbird      9
# 9     Historical        Northern Lapwing      9
# 10    Historical              Gray Heron      7
# 11    Historical       Eurasian Blackcap      6
# 12    Historical     European Greenfinch      6
# 13    Historical     Great Crested Grebe      6
# 14    Historical                 Mallard      6
# 15    Historical      Common Wood-Pigeon      5
# 16    Historical      Eurasian Spoonbill      5
# 17    Historical      European Stonechat      5
# 18    Incidental            Carrion Crow     21
# 19    Incidental      Common Wood-Pigeon     16
# 20    Incidental        Eurasian Jackdaw     16
# 21    Incidental         Eurasian Magpie     15
# 22    Incidental           Graylag Goose     15
# 23    Incidental       Black-headed Gull     14
# 24    Incidental                 Mallard     14
# 25    Incidental       European Starling     13
# 26    Incidental              Gray Heron     13
# 27    Incidental               Great Tit     13
# 28    Stationary       Black-headed Gull     44
# 29    Stationary        Eurasian Jackdaw     41
# 30    Stationary           Eurasian Coot     40
# 31    Stationary               Great Tit     39
# 32    Stationary            Carrion Crow     37
# 33    Stationary      Eurasian Blackbird     37
# 34    Stationary       Eurasian Blue Tit     37
# 35    Stationary           Graylag Goose     34
# 36    Stationary                 Mallard     34
# 37    Stationary         Great Cormorant     33
# 38     Traveling           Eurasian Coot    208
# 39     Traveling                 Mallard    204
# 40     Traveling      Common Wood-Pigeon    198
# 41     Traveling      Eurasian Blackbird    196
# 42     Traveling            Carrion Crow    176
# 43     Traveling           Graylag Goose    174
# 44     Traveling               Great Tit    173
# 45     Traveling         Eurasian Magpie    165
# 46     Traveling       Eurasian Blue Tit    159
# 47     Traveling       Black-headed Gull    158

# %%
top_birds_by_protocol_code = data.groupby(['PROTOCOL CODE', 'COMMON NAME']).size().reset_index(name='COUNT')
top_10_by_protocol_code = top_birds_by_protocol_code.groupby('PROTOCOL CODE').apply(lambda x: x.nlargest(10, 'COUNT')).reset_index(drop=True)
print(top_10_by_protocol_code)
# Out:
#    PROTOCOL CODE             COMMON NAME  COUNT
# 0            P20            Carrion Crow     21
# 1            P20      Common Wood-Pigeon     16
# 2            P20        Eurasian Jackdaw     16
# 3            P20         Eurasian Magpie     15
# 4            P20           Graylag Goose     15
# 5            P20       Black-headed Gull     14
# 6            P20                 Mallard     14
# 7            P20       European Starling     13
# 8            P20              Gray Heron     13
# 9            P20               Great Tit     13
# 10           P21       Black-headed Gull     44
# 11           P21        Eurasian Jackdaw     41
# 12           P21           Eurasian Coot     40
# 13           P21               Great Tit     39
# 14           P21            Carrion Crow     37
# 15           P21      Eurasian Blackbird     37
# 16           P21       Eurasian Blue Tit     37
# 17           P21           Graylag Goose     34
# 18           P21                 Mallard     34
# 19           P21         Great Cormorant     33
# 20           P22           Eurasian Coot    208
# 21           P22                 Mallard    204
# 22           P22      Common Wood-Pigeon    198
# 23           P22      Eurasian Blackbird    196
# 24           P22            Carrion Crow    176
# 25           P22           Graylag Goose    174
# 26           P22               Great Tit    173
# 27           P22         Eurasian Magpie    165
# 28           P22       Eurasian Blue Tit    159
# 29           P22       Black-headed Gull    158
# 30           P33            Barn Swallow      1
# 31           P33            Common Swift      1
# 32           P33       Eurasian Blackcap      1
# 33           P33  Eurasian Marsh-Harrier      1
# 34           P33        Eurasian Wryneck      1
# 35           P33               Great Tit      1
# 36           P33           Marsh Warbler      1
# 37           P33                 Redwing      1
# 38           P62      Eurasian Blackbird      9
# 39           P62        Northern Lapwing      9
# 40           P62              Gray Heron      7
# 41           P62       Eurasian Blackcap      6
# 42           P62     European Greenfinch      6
# 43           P62     Great Crested Grebe      6
# 44           P62                 Mallard      6
# 45           P62      Common Wood-Pigeon      5
# 46           P62      Eurasian Spoonbill      5
# 47           P62      European Stonechat      5

# %%
protocols_of_interest = ['Stationary', 'Traveling', 'Historical', 'Incidental']
filtered_data = data[data['PROTOCOL TYPE'].isin(protocols_of_interest)]
bird_counts_by_protocol = filtered_data.groupby(['PROTOCOL TYPE', 'COMMON NAME']).size().reset_index(name='COUNT')


N = 10
top_birds_by_protocol = bird_counts_by_protocol.groupby('PROTOCOL TYPE').apply(lambda x: x.nlargest(N, 'COUNT')).reset_index(drop=True)

plt.figure(figsize=(8, 6))  # Adjust width here
sns.swarmplot(data=top_birds_by_protocol, x='PROTOCOL TYPE', y='COUNT', hue='COMMON NAME', palette=palette, size=6, marker='D')
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1))
plt.title('Swarm plot of Most Sighted Birds for Each Protocol')
plt.savefig('../images/bird_by_sighting_type.png', bbox_inches='tight')  # Add bbox_inches parameter
plt.show()

# %%
from scipy.stats import chi2_contingency

# this includes frequencies of less than 5 for the categorial values

#Filter data
# this includes frequencies of less than 5 for the categorial values

stat_protocols_of_interest = ['Stationary', 'Traveling', 'Historical', 'Incidental']
bird_frequencies = data.groupby(['PROTOCOL TYPE', 'COMMON NAME']).size().reset_index(name='COUNT')
filtered_data = data[data['PROTOCOL TYPE'].isin(stat_protocols_of_interest)]


# Construct contingency table
contingency_table = pd.crosstab(filtered_data['COMMON NAME'], filtered_data['PROTOCOL TYPE'])

# Performing the Chi-squared test
chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-squared Statistic: {chi2_stat}")
print(f"P-value: {p_val}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies Table:")
print(expected)

if p_val < 0.05:
    print("The observed distribution of bird sightings is dependent on the protocol code.")
else:
    print("The observed distribution of bird sightings is independent of the protocol code.")
# Out:
# Chi-squared Statistic: 1324.9197540938808
# P-value: 7.970435261335829e-28
# Degrees of Freedom: 807
# Expected Frequencies Table:
# [[0.3082466  0.63650921 1.51220977 7.54303443]
#  [0.03082466 0.06365092 0.15122098 0.75430344]
#  [0.03082466 0.06365092 0.15122098 0.75430344]
#  ...
#  [0.06164932 0.12730184 0.30244195 1.50860689]
#  [0.03082466 0.06365092 0.15122098 0.75430344]
#  [0.03082466 0.06365092 0.15122098 0.75430344]]
# The observed distribution of bird sightings is dependent on the protocol code.

# %%
from scipy.stats import chi2_contingency

# Filter data
stat_protocols_of_interest5 = ['Stationary', 'Traveling', 'Historical', 'Incidental']
bird_frequencies5 = data.groupby(['PROTOCOL TYPE', 'COMMON NAME']).size().reset_index(name='COUNT')

# filtered_data = data[data['PROTOCOL TYPE'].isin(stat_protocols_of_interest)]

# filtering by frequency greater than 5
filtered_bird_frequencies5 = bird_frequencies5[bird_frequencies5['COUNT'] > 5]


# Construct contingency table
contingency_table5 = pd.crosstab(filtered_bird_frequencies5['COMMON NAME'], filtered_bird_frequencies['PROTOCOL TYPE'])

# Performing the Chi-squared test
chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table5)

print(f"Chi-squared Statistic: {chi2_stat}")
print(f"P-value: {p_val}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies Table:")
print(expected)

if p_val < 0.05:
    print("The observed distribution of bird sightings is dependent on the protocol code.")
else:
    print("The observed distribution of bird sightings is independent of the protocol code.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 14
#      10 filtered_bird_frequencies5 = bird_frequencies5[bird_frequencies5['COUNT'] > 5]
#      13 # Construct contingency table
# ---> 14 contingency_table5 = pd.crosstab(filtered_bird_frequencies5['COMMON NAME'], filtered_bird_frequencies['PROTOCOL TYPE'])
#      16 # Performing the Chi-squared test
#      17 chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table5)
#
# NameError: name 'filtered_bird_frequencies' is not defined

# %% [markdown]
# We have different p-values when filtering for > 5 (recommended for chi-test) so we can conclude the distribution of sightings is independent

# %%
# Group by STATE and count the sightings
area_sightings = data.groupby('STATE').size().sort_values(ascending=False)

# Display top areas
print(area_sightings)

# %%
# Assuming 'data' is your DataFrame

# Group by 'STATE' and get the count of sightings
state_counts = data.groupby('STATE').size().sort_values(ascending=False)

# Create a mapping from 'STATE' to 'STATE CODE'
state_code_mapping = dict(data[['STATE', 'STATE CODE']].drop_duplicates().values)

# Sort 'state_code_mapping' according to 'state_counts' to maintain the order
sorted_states = state_counts.index.tolist()
sorted_state_codes = [state_code_mapping[state] for state in sorted_states]

# Plot
plt.figure(figsize=(14, 7))
sns.barplot(x=sorted_state_codes, y=state_counts.values)
plt.xlabel("State Code")
plt.ylabel("Number of Sightings")
plt.title("Number of Sightings by State Code")

# Creating the legend
legend_patches = [plt.Line2D([0], [0], marker='o', color='w', label=f'{code}: {state_dict[code]}', markersize=10) for code in sorted_state_codes]
plt.legend(handles=legend_patches, loc='upper right', title="State Codes")

plt.tight_layout()
plt.show()

# %%
population_data = pd.read_csv(r'..\data\raw\population_by_state.csv', sep=";")
print(population_data)


population_data.head()

# %%
plt.figure(figsize=(12, 7))
colors = sns.color_palette("coolwarm", len(merged_data))
plt.bar(merged_data['STATE'], merged_data['POPULATION'], color=colors)
plt.ylabel('Population')
plt.title('Population by State')
plt.xticks(rotation=45)
plt.tight_layout()

# shows actual nums without sci. notation
y_ticks = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(y) for y in y_ticks])

plt.show()

# %%
print(merged_data.columns)

# %%
import calendar

# Extract month from OBSERVATION DATE
data['MONTH'] = pd.to_datetime(data['OBSERVATION DATE']).dt.month



# Plot sightings
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_sightings.index, y=monthly_sightings.values)

# Set month abbreviations as x labels
plt.xticks(monthly_sightings.index, [calendar.month_abbr[i] for i in monthly_sightings.index])

plt.title('Bird Sightings by Month - Seasonality')
plt.xlabel('Month')
plt.ylabel('Number of Sightings')
plt.grid(True)
plt.show()
